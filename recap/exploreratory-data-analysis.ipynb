# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_csv("data/mexico-real-estate-clean.csv")

fig = px.scatter_mapbox(
    df,
    lat="lat",
    lon="lon",
    center={"lat":19.43, "lon":-99.13}, #centers in mexico city
    width=800,
    height=800,
    hover_data=["price_usd"],
)

fig.update_layout(
    mapbox_style = "open-street-map"
)
fig.show()
# Out:
# /tmp/ipykernel_6532/2984903452.py:7: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = px.scatter_mapbox(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a DataFrame with the data (you'll need to estimate the exact values from the bars)
data = {
    'Year': [2005, 2010, 2015, 2020],
    'H5N1': [5, 15, 20, 10],  # Estimated values
    'H5N2': [2, 8, 12, 5],
    'H5N6': [0, 3, 15, 8],
    'H5N8': [0, 5, 18, 12],
    'H7N1': [1, 2, 3, 1],
    'H7N3': [2, 4, 5, 3],
    'H7N7': [1, 3, 4, 2],
    'H7N9': [0, 5, 12, 8],
    'Multiple subtypes': [3, 8, 10, 6]
}

df = pd.DataFrame(data)
df.set_index('Year', inplace=True)

# Create stacked bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Get unique colors for each subtype
colors = plt.cm.tab20(np.linspace(0, 1, len(df.columns)))

# Plot each subtype
bottom = np.zeros(len(df))
for i, col in enumerate(df.columns):
    ax.bar(df.index, df[col], bottom=bottom, label=col, color=colors[i])
    bottom += df[col]

# Customize the plot
ax.set_title('Temporal Description - Distribution of Publication Date for Different Avian Influenza Subtypes', pad=20)
ax.set_xlabel('Year of Publication')
ax.set_ylabel('Number of Article(s)')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Year': [2005, 2010, 2015, 2020],
    'H5N1': [5, 15, 20, 10],
    'H5N2': [2, 8, 12, 5],
    'H5N6': [0, 3, 15, 8],
    'H5N8': [0, 5, 18, 12],
    'H7N1': [1, 2, 3, 1],
    'H7N3': [2, 4, 5, 3],
    'H7N7': [1, 3, 4, 2],
    'H7N9': [0, 5, 12, 8],
    'Multiple Subtypes': [3, 8, 10, 6]
}

df = pd.DataFrame(data).set_index('Year')
df.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title("Publication Distribution by Avian Influenza Subtype")
plt.ylabel("Number of Articles")
plt.xlabel("Year of Publication")
plt.legend(bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data
data = {
    'Year': [2005, 2010, 2015, 2020],
    'H5N1': [5, 15, 20, 10],
    'H5N2': [2, 8, 12, 5],
    'H5N6': [0, 3, 15, 8],
    'H5N8': [0, 5, 18, 12],
    'H7N1': [1, 2, 3, 1],
    'H7N3': [2, 4, 5, 3],
    'H7N7': [1, 3, 4, 2],
    'H7N9': [0, 5, 12, 8],
    'Multiple Subtypes': [3, 8, 10, 6]
}

df = pd.DataFrame(data).set_index('Year')

# Create plot with reduced scale
plt.figure(figsize=(8, 4))  # Smaller figure size (width, height)

# Plot stacked bars
df.plot(kind='bar', stacked=True, width=0.6)  # Reduced bar width

# Adjust axis limits if needed (optional)
plt.ylim(0, 55)  # Y-axis limit slightly above max stack height
plt.xlim(-0.5, len(df)-0.5)  # X-axis limits to remove extra space

# Customize appearance
plt.title("Publication Distribution by Avian Influenza Subtype", fontsize=10)
plt.ylabel("Number of Articles", fontsize=9)
plt.xlabel("Year of Publication", fontsize=9)
plt.xticks(rotation=0, fontsize=8)
plt.yticks(fontsize=8)

# Adjust legend
plt.legend(fontsize=8, bbox_to_anchor=(1.05, 1))

plt.tight_layout()
plt.show()

# %%
### Categorical Data
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_csv("data/mexico-real-estate-clean.csv")

df["state"].nunique()  #gives the number of unique values in the state column
df["state"].unique() #gives an array of the represented values in the column state
df["state"].value_counts().head(10) # gives us the series of the column "state", that is how frequent th entries are per state
df[["price_usd","area_m2"]].describe()


"""Creating a boxplot"""
plt.boxplot(df["price_usd"], vert = False)
plt.xlabel("price(USD)")
# Out:
# Text(0.5, 0, 'price(USD)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Complete data including all visible years
data = {
    'Year': [2000, 2005, 2010, 2015, 2020, 2025],
    'H5N1': [0, 5, 15, 20, 10, 2],
    'H5N2': [0, 2, 8, 12, 5, 1],
    'H5N6': [0, 0, 3, 15, 8, 3],
    'H5N8': [0, 0, 5, 18, 12, 4],
    'H7N1': [0, 1, 2, 3, 1, 0],
    'H7N3': [1, 2, 4, 5, 3, 1],
    'H7N7': [0, 1, 3, 4, 2, 0],
    'H7N9': [0, 0, 5, 12, 8, 2],
    'Multiple Subtypes': [0, 3, 8, 10, 6, 1]
}

df = pd.DataFrame(data).set_index('Year')

# Create plot
plt.figure(figsize=(10, 5))
df.plot(kind='bar', stacked=True, width=0.8)

# Customize
plt.title("Publication Distribution by Avian Influenza Subtype", pad=20)
plt.ylabel("Number of Articles")
plt.xlabel("Year of Publication")
plt.legend(bbox_to_anchor=(1.05, 1))
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_csv("data/mexico-real-estate-clean.csv")

"""Drawing a Histogram"""
"""Drawing an Histogram"""
plt.hist(df["area_m2"]);
plt.xlabel("Area (m2)")
plt.ylabel("frequency")
plt.title("Distributions of Homes Sizes")
# Out:
# Text(0.5, 1.0, 'Distributions of Homes Sizes')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Full dataset (15 years)
data = {
    'Year': range(2005, 2020),
    'H5N1': [4,5,6,8,10,12,14,16,18,20,22,18,15,12,10],
    'H5N2': [1,2,2,3,4,6,7,8,10,12,14,12,10,8,6],
    'H5N6': [0,0,0,0,0,1,2,3,6,9,12,10,8,6,5],
    'H5N8': [0,0,0,0,1,2,3,5,8,12,15,14,12,10,8],
    'H7N1': [0,1,1,1,1,1,1,2,2,2,3,2,2,1,1],
    'H7N3': [1,1,2,2,2,3,3,4,4,5,5,4,4,3,3],
    'H7N7': [0,0,1,1,1,2,2,2,3,3,4,3,2,2,1],
    'H7N9': [0,0,0,0,0,2,3,4,6,8,10,8,7,6,5],
    'Multiple': [2,2,3,3,4,5,6,7,8,9,10,8,7,6,5]
}

df = pd.DataFrame(data).set_index('Year')

# Plot settings to match the original image
plt.figure(figsize=(15,6))
colors = ['#1f77b4','#ff7f0e','#2ca02c','#d62728','#9467bd',
          '#8c564b','#e377c2','#7f7f7f','#bcbd22']  # Matplotlib default colors

df.plot(kind='bar', stacked=True, color=colors, width=0.8)

# Formatting to resemble the original
plt.title("Temporal Description - Distribution of Publication Date for Different Avian Influenza Subtypes", pad=20, fontsize=12)
plt.xlabel("Year of Publication", fontsize=10)
plt.ylabel("Number of Articles", fontsize=10)
plt.xticks(rotation=0, fontsize=9)
plt.yticks(fontsize=9)
plt.legend(title="Subtype", bbox_to_anchor=(1.02, 1), fontsize=9)
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.tight_layout()
plt.show()h

# %%
"""Answering Research Questions Based on The Mexico Real Estate Dataset"""

import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_csv("data/mexico-real-estate-clean.csv")

#Question 1: Do Housing prices vary by state?

#to answer, we plot the mean prices grouped by state on Bar charts to visualize the variation.

mean_price_by_state = df.groupby("state")["price_usd"].mean().sort_values(ascending = False)
mean_price_by_state.plot(
    kind="bar",
    ylabel ="Price in Usd",
    xlabel = "state",
    title = "Mean price in USD per State"
);

# %%
"""What is the price per square Metres"""

import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_csv("data/mexico-real-estate-clean.csv")


#Calculating price per square Metres and adding that to our DataFrame df

df["price_per_m2"] = df["price_usd"]/df['area_m2']
(
    df
    .groupby("state")["price_per_m2"]
    .mean().sort_values(ascending = False)
    .plot(
    kind = "bar",
    xlabel ="state",
    ylabel="Mean Price per square metres",
    title = "Mean house price per square meters by state",
    )
);

# %%
"""Is there a relationship between price and home sizes"""

#to answer the above question, we'll a scatterplot to visualize the corelation between the two datas

import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_csv("data/mexico-real-estate-clean.csv")

#Drawing the scatterplot

plt.scatter(x = df["area_m2"], y = df["price_usd"])
plt.xlabel("Area in square meters")
plt.ylabel("Price (USD)")
plt.title("Area vs Price");

# %%
"""Determining The Correlation between area and price"""

import pandas as pd  


df = pd.read_csv("data/mexico-real-estate-clean.csv")

#Correlation is a statistical measure that descirbes 
# the extent of a linear relationship between two variables

#using pandas we can use the function corr() to calculate the correlation between two columns
#ie for this case we can use the columns "area_m2" and "price_usd"

p_correlation =df["area_m2"].corr(df["price_usd"])

print("p_correlation:", p_correlation)
# Out:
# p_correlation: 0.585518245323206

# %%
"""Exploring the relationship Between Area and price in individual states, in this Case we use the MORELOS STATE"""

#To achieve this, we create a new dataframe that only consists of rows where state is Morelos

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/mexico-real-estate-clean.csv")

df_morelos = df[df["state"] == "Morelos"]

#Using the df_morelos Dataframe, a subset of the df Dataframe, 
#we'll visualize a scatter plot do dtermine the relationship bnetween area and price in the Morelos state

plt.scatter(x=df_morelos["area_m2"], y=df_morelos["price_usd"])
plt.xlabel("Area (m²)")
plt.ylabel("Price (USD)")
plt.title("Morelos: Area vs Price")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 16
#      12 #Using the df_morelos Dataframe, a subset of the df Dataframe,
#      13 #we'll visualize a scatter plot do dtermine the relationship bnetween area and price in the Morelos state
#      15 plt.scatter(x=df_morelos["area_m2"], y=df_morelos["price_usd"])
# ---> 16 plt.xlabel("Area (m²)")
#      17 plt.ylabel("Price (USD)")
#      18 plt.title("Morelos: Area vs Price")
#
# TypeError: 'str' object is not callable

# %%
"""Determining the correlation coefficient for the relation between Area and Price for the Morelos State"""

import pandas as pd

df = pd.read_csv("data/mexico-real-estate-clean.csv")
df_morelos = df[df["state"] == "Morelos"]

P_coefficient = df_morelos["area_m2"].corr(df_morelos["price_usd"])
print(P_coefficient)
# Out:
# 0.8498077608713708
